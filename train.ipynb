# %%
import os

# %%
# %pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.5 MB 35.6 MB/s
# ...
#      |████████████████████████████████| 163 kB 88.4 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 78.7 MB/s
# ...

# %%
# %pip install small-text[transformer]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 178 kB 28.4 MB/s
# WARNING: small-text 1.1.1 does not provide the extra 'transformer'
# ...

# %%
import numpy as np
import torch
from sklearn.metrics import accuracy_score
from small_text import TransformersDataset, TransformerModelArguments, TransformerBasedClassificationFactory, \
    GreedyCoreset

# %%
os.getcwd()
os.chdir('drive')
os.chdir('MyDrive')
os.chdir('ai6103')
os.chdir('DL-GroupProject')

# %%
os.getcwd()
# Out:
# '/content/drive/MyDrive/ai6103/DL-GroupProject'

# %%
import tensorflow as tf

# %%
import torch

# %%
torch.cuda.empty_cache()

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# %run GRec_TF_Pretrain_topk.py
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# [4 3 0]
# []
# 1.0
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: calling expand_dims (from tensorflow.python.ops.array_ops) with dim is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the `axis` argument instead
# ('len(items)', 117761)
# FFFFF

# %% [markdown]
# corset

# %%
# %run PeterRec_noncau_parallel_classifier.py
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# [4 3 0]
# []
# 1.0
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: calling expand_dims (from tensorflow.python.ops.array_ops) with dim is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the `axis` argument instead
# ('len(all_samples)', 100000)
# ('len(items)', 352112)
# ('len(targets)', 6)
# [[-0.07446209 -0.04646964 -0.0533956  ... -0.006444   -0.00874368
#   -0.02387206]
#  [-0.30740803  0.01624344 -0.19160087 ...  0.01847769 -0.06107564
#    0.03372553]
#  [-0.07229868 -0.02782907  0.05660037 ... -0.00815267 -0.07680246
#    0.11950072]
#  ...
# ...

# %%
# %run PeterRec_noncau_parallel_classifier.py
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# [4 3 0]
# []
# 1.0
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: calling expand_dims (from tensorflow.python.ops.array_ops) with dim is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the `axis` argument instead
# ('len(all_samples)', 100000)
# ('len(items)', 352112)
# ('len(targets)', 6)
# [[-0.07446209 -0.04646964 -0.0533956  ... -0.006444   -0.00874368
#   -0.02387206]
#  [-0.30740803  0.01624344 -0.19160087 ...  0.01847769 -0.06107564
#    0.03372553]
#  [-0.07229868 -0.02782907  0.05660037 ... -0.00815267 -0.07680246
#    0.11950072]
#  ...
# ...

# %%
# %run PeterRec_noncau_parallel_classifier.py
# Out:
# ('len(all_samples)', 100000)
# ('len(items)', 352112)
# ('len(targets)', 6)
# [[-0.07446209 -0.04646964 -0.0533956  ... -0.006444   -0.00874368
#   -0.02387206]
#  [-0.30740803  0.01624344 -0.19160087 ...  0.01847769 -0.06107564
#    0.03372553]
#  [-0.07229868 -0.02782907  0.05660037 ... -0.00815267 -0.07680246
#    0.11950072]
#  ...
#  [ 0.01582698  0.00832158  0.02750127 ... -0.02865618  0.01989465
#   -0.02128967]
#  [-0.02417357  0.08913273  0.04159573 ... -0.01441422  0.04290155
#   -0.02610734]
#  [-0.02634715 -0.04973257  0.03602069 ... -0.02721033 -0.05475942
#    0.04348999]]
# -------------------------------------------------------Accuracy
# ('Accuracy hit:', 0.5)
# -------------------------------------------------------Accuracy
# ('Accuracy hit:', 0.5074404761904762)
# -------------------------------------------------------Accuracy
# ('Accuracy hit:', 0.49107142857142855)
# -------------------------------------------------------Accuracy
# ...

# %%
# %run a_make_active_learner_transfomer.py
# Out:
# True
# ('len(all_samples)', 10000)
# ('len(items)', 117761)
# ('len(targets)', 6)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /content/drive/MyDrive/ai6103/DL-GroupProject/a_make_active_learner_transfomer.py in <module>
#     140     train_set, valid_set = all_samples[:dev_sample_index], all_samples[dev_sample_index:]
#     141
# --> 142     act = ActiveLearner(train_set, 50)
#     143
#     144     # query = act.query()
#
# TypeError: __init__() missing 1 required positional argument: 'class_count'

# %% [markdown]
# test

# %%
# 1000
# %run PeterRec_noncau_parallel_classifier.py
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# [4 3 0]
# []
# 1.0
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: calling expand_dims (from tensorflow.python.ops.array_ops) with dim is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the `axis` argument instead
# ('len(all_samples)', 100000)
# ('len(items)', 352112)
# ('len(targets)', 6)
# [[-0.07446209 -0.04646964 -0.0533956  ... -0.006444   -0.00874368
#   -0.02387206]
#  [-0.30740803  0.01624344 -0.19160087 ...  0.01847769 -0.06107564
#    0.03372553]
#  [-0.07229868 -0.02782907  0.05660037 ... -0.00815267 -0.07680246
#    0.11950072]
#  ...
# ...

# %%
# 600
# %run PeterRec_noncau_parallel_classifier.py
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: calling expand_dims (from tensorflow.python.ops.array_ops) with dim is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the `axis` argument instead
# ('len(all_samples)', 100000)
# ('len(items)', 352112)
# ('len(targets)', 6)
# [[-0.07446209 -0.04646964 -0.0533956  ... -0.006444   -0.00874368
#   -0.02387206]
#  [-0.30740803  0.01624344 -0.19160087 ...  0.01847769 -0.06107564
#    0.03372553]
#  [-0.07229868 -0.02782907  0.05660037 ... -0.00815267 -0.07680246
#    0.11950072]
#  ...
#  [ 0.01582698  0.00832158  0.02750127 ... -0.02865618  0.01989465
#   -0.02128967]
#  [-0.02417357  0.08913273  0.04159573 ... -0.01441422  0.04290155
#   -0.02610734]
#  [-0.02634715 -0.04973257  0.03602069 ... -0.02721033 -0.05475942
#    0.04348999]]
# ...

# %%
# %run PeterRec_noncau_parallel_classifier.py
# Out:
# ('len(all_samples)', 100000)
# ('len(items)', 352112)
# ('len(targets)', 6)
# [[-0.07446209 -0.04646964 -0.0533956  ... -0.006444   -0.00874368
#   -0.02387206]
#  [-0.30740803  0.01624344 -0.19160087 ...  0.01847769 -0.06107564
#    0.03372553]
#  [-0.07229868 -0.02782907  0.05660037 ... -0.00815267 -0.07680246
#    0.11950072]
#  ...
#  [ 0.01582698  0.00832158  0.02750127 ... -0.02865618  0.01989465
#   -0.02128967]
#  [-0.02417357  0.08913273  0.04159573 ... -0.01441422  0.04290155
#   -0.02610734]
#  [-0.02634715 -0.04973257  0.03602069 ... -0.02721033 -0.05475942
#    0.04348999]]
# 0
# -------------------------------------------------------train1
# LOSS: 1.2477737665176392\Reg_LOSS: 0.0016055795131251216	ITER: 0	BATCH_NO: 124	 STEP:124	 total_batches:125.0
# ('TIME FOR BATCH', 5.43994927406311)
# ('TIME FOR ITER (mins)', 11.333227654298147)
# -------------------------------------------------------Accuracy
# ('Accuracy hit:', 0.47767857142857145)
# 1
# ...

# %%
# %run GRec_TF_Pretrain_topk.py
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# [4 3 0]
# []
# 1.0
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: calling expand_dims (from tensorflow.python.ops.array_ops) with dim is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the `axis` argument instead
# ('len(items)', 123938)
# FFFFF
# -------------------------------------------------------train1
# LOSS: 5.8688201904296875	ITER: 1	BATCH_NO: 30	 STEP:312	 total_batches:281.25
# ('TIME FOR BATCH', 0.043396949768066406)
# -------------------------------------------------------test1
# LOSS: [4.113256]	ITER: 1	BATCH_NO: 0	 STEP:312	 total_batches:31.25
# ...

# %%
# %run PeterRec_noncau_parallel_classifier.py
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# [4 3 0]
# []
# 1.0
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: calling expand_dims (from tensorflow.python.ops.array_ops) with dim is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the `axis` argument instead
# ('len(all_samples)', 10000)
# ('len(items)', 117761)
# ('len(targets)', 6)
# [[ 0.00925385  0.00991653 -0.02167107 ...  0.00903323 -0.01013254
#   -0.00126953]
#  [ 0.05143973  0.03240489  0.06431372 ...  0.05513695 -0.02303935
#   -0.00637356]
#  [-0.05949183 -0.00429206  0.07805542 ... -0.00819906 -0.02331647
#   -0.04548696]
#  ...
# ...

# %%
# %run PeterRec_noncau_parallel_classifier.py
# Out:
# all_samplesint64
# ('len(all_samples)', 10000)
# ('len(items)', 117761)
# ('len(targets)', 6)
# [[ 0.00925385  0.00991653 -0.02167107 ...  0.00903323 -0.01013254
#   -0.00126953]
#  [ 0.05143973  0.03240489  0.06431372 ...  0.05513695 -0.02303935
#   -0.00637356]
#  [-0.05949183 -0.00429206  0.07805542 ... -0.00819906 -0.02331647
#   -0.04548696]
#  ...
#  [-0.01270036  0.01538328  0.01083106 ... -0.0012201   0.0112446
#    0.01128637]
#  [ 0.0330256   0.00303034 -0.01253023 ... -0.00227195  0.00899311
#   -0.00119764]
#  [ 0.02404178  0.02814781 -0.02375346 ...  0.03165634 -0.02199906
#    0.00475263]]
# 0
# -------------------------------------------------------train1
# LOSS: 1.3637855052947998\Reg_LOSS: 0.0013948304113000631	ITER: 0	BATCH_NO: 499	 STEP:499	 total_batches:500.0
# ('TIME FOR BATCH', 16.134050130844116)
# ('TIME FOR ITER (mins)', 134.4504177570343)
# ------------------------------------------------------- valid Accuracy
# ...

# %%
# %run PeterRec_noncau_parallel_classifier.py
# Out:
# ('len(all_samples)', 10000)
# ('len(items)', 123960)
# ('len(targets)', 8)
# [[-0.07743596 -0.06166476  0.01538035 ... -0.05620319 -0.0226805
#   -0.06780235]
#  [ 0.01371549  0.12166899 -0.00505747 ...  0.05176482 -0.00511115
#    0.00068528]
#  [-0.08248068  0.03201909  0.05920622 ... -0.02997927  0.06714078
#   -0.00397161]
#  ...
#  [ 0.001895   -0.03000796 -0.01679019 ... -0.00289529 -0.02417786
#    0.01576148]
#  [ 0.04139248 -0.0070689   0.00300987 ...  0.01801945 -0.01726617
#    0.02157392]
#  [ 0.03269431  0.02525385 -0.01028174 ...  0.0300835  -0.02241601
#   -0.04973428]]
# okkkkkk
# 0
# -------------------------------------------------------train1
# LOSS: 1.2900267839431763\Reg_LOSS: 0.0027139720041304827	ITER: 0	BATCH_NO: 24	 STEP:24	 total_batches:25.0
# ('TIME FOR BATCH', 9.931687116622925)
# ('TIME FOR ITER (mins)', 4.138202965259552)
# ------------------------------------------------------- valid Accuracy
# ('Accuracy hit:', 0.35714285714285715)
# ...

# %%
tmp = list(open('data/coresetage1000-num.csv', "r").readlines())
tmpp = [s.split(',') for s in tmp]
tmppp = np.array(tmpp, dtype=np.int64)

# %%
tmppp
# Out:
# array([[     0,      1,      1, ...,     71,      0,      3],
#        [     0,   7752,   9725, ...,   6090,      0,      1],
#        [     0,      1,      1, ...,   7335,      0,      8],
#        ...,
#        [     0,    842,  17160, ...,   1128,      0,      1],
#        [     0,  16463, 107560, ...,  17004,      0,      1],
#        [     0, 113942,   9448, ...,     90,      0,      3]])

# %%
# %run PeterRec_noncau_parallel_classifier.py
# Out:
# ('len(all_samples)', 10000)
# ('len(items)', 123960)
# ('len(targets)', 8)
# [[-0.07743596 -0.06166476  0.01538035 ... -0.05620319 -0.0226805
#   -0.06780235]
#  [ 0.01371549  0.12166899 -0.00505747 ...  0.05176482 -0.00511115
#    0.00068528]
#  [-0.08248068  0.03201909  0.05920622 ... -0.02997927  0.06714078
#   -0.00397161]
#  ...
#  [ 0.001895   -0.03000796 -0.01679019 ... -0.00289529 -0.02417786
#    0.01576148]
#  [ 0.04139248 -0.0070689   0.00300987 ...  0.01801945 -0.01726617
#    0.02157392]
#  [ 0.03269431  0.02525385 -0.01028174 ...  0.0300835  -0.02241601
#   -0.04973428]]
# 0
# -------------------------------------------------------train1
# LOSS: 1.2166653871536255\Reg_LOSS: 0.002435175236314535	ITER: 0	BATCH_NO: 499	 STEP:499	 total_batches:500.0
# ('TIME FOR BATCH', 15.898271799087524)
# ('TIME FOR ITER (mins)', 132.48559832572937)
# ------------------------------------------------------- valid Accuracy
# ...

# %%
import matplotlib.pyplot as plt
import time

# %%
# %run PeterRec_noncau_parallel_classifier.py
# Out:
# ('len(all_samples)', 10000)
# ('len(items)', 123960)
# ('len(targets)', 8)
# [0.000e+00 2.202e+03 4.644e+03 ... 1.000e+01 0.000e+00 4.000e+00]
# [[0.000e+00 2.202e+03 4.644e+03 ... 9.700e+01 0.000e+00 1.000e+00]
#  [0.000e+00 1.000e+00 1.000e+00 ... 3.690e+02 0.000e+00 2.000e+00]
#  [0.000e+00 1.000e+00 1.000e+00 ... 1.571e+03 0.000e+00 3.000e+00]
#  ...
#  [0.000e+00 1.000e+00 1.000e+00 ... 5.510e+02 0.000e+00 4.000e+00]
#  [0.000e+00 1.000e+00 1.000e+00 ... 7.900e+01 0.000e+00 2.000e+00]
#  [0.000e+00 1.000e+00 1.000e+00 ... 1.000e+01 0.000e+00 4.000e+00]]
# [[-0.07743596 -0.06166476  0.01538035 ... -0.05620319 -0.0226805
#   -0.06780235]
#  [ 0.01371549  0.12166899 -0.00505747 ...  0.05176482 -0.00511115
#    0.00068528]
#  [-0.08248068  0.03201909  0.05920622 ... -0.02997927  0.06714078
#   -0.00397161]
#  ...
#  [ 0.001895   -0.03000796 -0.01679019 ... -0.00289529 -0.02417786
#    0.01576148]
#  [ 0.04139248 -0.0070689   0.00300987 ...  0.01801945 -0.01726617
#    0.02157392]
# ...

# %%
# %run PeterRec_noncau_parallel_classifier.py

# %%
# %run PeterRec_noncau_parallel_classifier.py
# Out:
# ('len(all_samples)', 10000)
# ('len(items)', 117761)
# ('len(targets)', 6)
# [0.00e+00 1.00e+00 1.00e+00 ... 2.51e+03 0.00e+00 3.00e+00]
# [[0.0000e+00 1.0000e+00 1.0000e+00 ... 6.3000e+02 0.0000e+00 1.0000e+00]
#  [0.0000e+00 1.0000e+00 1.0000e+00 ... 1.8519e+04 0.0000e+00 1.0000e+00]
#  [0.0000e+00 4.3120e+03 2.7350e+03 ... 2.8356e+04 0.0000e+00 1.0000e+00]
#  ...
#  [0.0000e+00 1.0000e+00 1.0000e+00 ... 3.6445e+04 0.0000e+00 2.0000e+00]
#  [0.0000e+00 1.0000e+00 1.0000e+00 ... 4.6420e+03 0.0000e+00 1.0000e+00]
#  [0.0000e+00 1.0000e+00 1.0000e+00 ... 2.5100e+03 0.0000e+00 3.0000e+00]]
# pp1
# pp2
# [[-0.04426406 -0.07810012 -0.00648522 ... -0.04054989 -0.02787911
#   -0.07533555]
#  [-0.01551472  0.01744387  0.03945875 ... -0.05896433 -0.01512137
#    0.06081801]
#  [ 0.06239419  0.17461778  0.06044212 ...  0.01600982  0.05622429
#   -0.02204405]
#  ...
#  [ 0.02257314  0.02387777 -0.06157823 ...  0.04618987 -0.02778204
#   -0.03778286]
# ...

# %%
# gender
# %run PeterRec_noncau_parallel_classifier.py
# Out:
# ('len(all_samples)', 10000)
# ('len(items)', 123938)
# ('len(targets)', 2)
# pp1
# pp2
# [[-0.01605127 -0.03688305 -0.06625882 ... -0.06415381 -0.0131299
#   -0.04033688]
#  [ 0.05534801  0.05074071 -0.12720883 ... -0.1568805  -0.05430361
#    0.00623757]
#  [ 0.05696552  0.13475962 -0.01044716 ... -0.08151836 -0.02845905
#   -0.07766074]
#  ...
#  [ 0.02752712  0.02977758 -0.01664803 ... -0.01523982 -0.01738345
#   -0.06337102]
#  [ 0.01188344  0.01602031  0.00217294 ...  0.02178446  0.02002777
#   -0.03279328]
#  [-0.02543662 -0.0163812  -0.02337425 ... -0.02729406  0.01655482
#   -0.01034165]]
# okkkkkk
# 0
# -------------------------------------------------------train1
# LOSS: 0.4473809599876404\Reg_LOSS: 0.0011628192150965333	ITER: 0	BATCH_NO: 24	 STEP:24	 total_batches:25.0
# ('TIME FOR BATCH', 3.9760818481445312)
# ('TIME FOR ITER (mins)', 1.6567007700602214)
# ------------------------------------------------------- valid Accuracy
# ('Accuracy hit:', 0.8809523809523809)
# ...

# %%
# %run PeterRec_noncau_parallel_classifier.py

# %%
# %run PeterRec_noncau_parallel_classifier.py
# Out:
# ('len(all_samples)', 10000)
# ('len(items)', 123938)
# ('len(targets)', 2)
# [  0.   1.   1. ... 558.   0.   1.]
# [[0.0000e+00 1.0000e+00 1.0000e+00 ... 5.7453e+04 0.0000e+00 1.0000e+00]
#  [0.0000e+00 1.0000e+00 1.0000e+00 ... 5.0706e+04 0.0000e+00 1.0000e+00]
#  [0.0000e+00 1.0000e+00 1.0000e+00 ... 6.9300e+02 0.0000e+00 1.0000e+00]
#  ...
#  [0.0000e+00 1.0000e+00 1.0000e+00 ... 5.9473e+04 0.0000e+00 1.0000e+00]
#  [0.0000e+00 1.0000e+00 1.0000e+00 ... 2.0511e+04 0.0000e+00 1.0000e+00]
#  [0.0000e+00 1.0000e+00 1.0000e+00 ... 5.5800e+02 0.0000e+00 1.0000e+00]]
# pp1
# pp2
# [[-0.01605127 -0.03688305 -0.06625882 ... -0.06415381 -0.0131299
#   -0.04033688]
#  [ 0.05534801  0.05074071 -0.12720883 ... -0.1568805  -0.05430361
#    0.00623757]
#  [ 0.05696552  0.13475962 -0.01044716 ... -0.08151836 -0.02845905
#   -0.07766074]
#  ...
#  [ 0.02752712  0.02977758 -0.01664803 ... -0.01523982 -0.01738345
#   -0.06337102]
#  [ 0.01188344  0.01602031  0.00217294 ...  0.02178446  0.02002777
# ...

# %%
# %run PeterRec_noncau_parallel_classifier.py
# Out:
# ('len(all_samples)', 10000)
# ('len(items)', 123938)
# ('len(targets)', 2)
# [  0.   1.   1. ... 558.   0.   1.]
# [[0.0000e+00 1.0000e+00 1.0000e+00 ... 5.7453e+04 0.0000e+00 1.0000e+00]
#  [0.0000e+00 1.0000e+00 1.0000e+00 ... 5.0706e+04 0.0000e+00 1.0000e+00]
#  [0.0000e+00 1.0000e+00 1.0000e+00 ... 6.9300e+02 0.0000e+00 1.0000e+00]
#  ...
#  [0.0000e+00 1.0000e+00 1.0000e+00 ... 5.9473e+04 0.0000e+00 1.0000e+00]
#  [0.0000e+00 1.0000e+00 1.0000e+00 ... 2.0511e+04 0.0000e+00 1.0000e+00]
#  [0.0000e+00 1.0000e+00 1.0000e+00 ... 5.5800e+02 0.0000e+00 1.0000e+00]]
# pp1
# pp2
# [[-0.01605127 -0.03688305 -0.06625882 ... -0.06415381 -0.0131299
#   -0.04033688]
#  [ 0.05534801  0.05074071 -0.12720883 ... -0.1568805  -0.05430361
#    0.00623757]
#  [ 0.05696552  0.13475962 -0.01044716 ... -0.08151836 -0.02845905
#   -0.07766074]
#  ...
#  [ 0.02752712  0.02977758 -0.01664803 ... -0.01523982 -0.01738345
#   -0.06337102]
#  [ 0.01188344  0.01602031  0.00217294 ...  0.02178446  0.02002777
# ...

# %%
# %run PeterRec_noncau_parallel_classifier.py
# Out:
# ('len(all_samples)', 10000)
# ('len(items)', 117761)
# ('len(targets)', 6)
# [0.00e+00 1.00e+00 1.00e+00 ... 2.51e+03 0.00e+00 3.00e+00]
# [[0.0000e+00 1.0000e+00 1.0000e+00 ... 6.3000e+02 0.0000e+00 1.0000e+00]
#  [0.0000e+00 1.0000e+00 1.0000e+00 ... 1.8519e+04 0.0000e+00 1.0000e+00]
#  [0.0000e+00 4.3120e+03 2.7350e+03 ... 2.8356e+04 0.0000e+00 1.0000e+00]
#  ...
#  [0.0000e+00 1.0000e+00 1.0000e+00 ... 3.6445e+04 0.0000e+00 2.0000e+00]
#  [0.0000e+00 1.0000e+00 1.0000e+00 ... 4.6420e+03 0.0000e+00 1.0000e+00]
#  [0.0000e+00 1.0000e+00 1.0000e+00 ... 2.5100e+03 0.0000e+00 3.0000e+00]]
# pp1
# pp2
# [[-0.04426406 -0.07810012 -0.00648522 ... -0.04054989 -0.02787911
#   -0.07533555]
#  [-0.01551472  0.01744387  0.03945875 ... -0.05896433 -0.01512137
#    0.06081801]
#  [ 0.06239419  0.17461778  0.06044212 ...  0.01600982  0.05622429
#   -0.02204405]
#  ...
#  [ 0.02257314  0.02387777 -0.06157823 ...  0.04618987 -0.02778204
#   -0.03778286]
# ...

# %%
# %run PeterRec_noncau_parallel_classifier.py
# Out:
# ('len(all_samples)', 10000)
# ('len(items)', 117761)
# ('len(targets)', 6)
# [0.00e+00 1.00e+00 1.00e+00 ... 2.51e+03 0.00e+00 3.00e+00]
# [[0.0000e+00 1.0000e+00 1.0000e+00 ... 6.3000e+02 0.0000e+00 1.0000e+00]
#  [0.0000e+00 1.0000e+00 1.0000e+00 ... 1.8519e+04 0.0000e+00 1.0000e+00]
#  [0.0000e+00 4.3120e+03 2.7350e+03 ... 2.8356e+04 0.0000e+00 1.0000e+00]
#  ...
#  [0.0000e+00 1.0000e+00 1.0000e+00 ... 3.6445e+04 0.0000e+00 2.0000e+00]
#  [0.0000e+00 1.0000e+00 1.0000e+00 ... 4.6420e+03 0.0000e+00 1.0000e+00]
#  [0.0000e+00 1.0000e+00 1.0000e+00 ... 2.5100e+03 0.0000e+00 3.0000e+00]]
# pp1
# pp2
# [[-0.04426406 -0.07810012 -0.00648522 ... -0.04054989 -0.02787911
#   -0.07533555]
#  [-0.01551472  0.01744387  0.03945875 ... -0.05896433 -0.01512137
#    0.06081801]
#  [ 0.06239419  0.17461778  0.06044212 ...  0.01600982  0.05622429
#   -0.02204405]
#  ...
#  [ 0.02257314  0.02387777 -0.06157823 ...  0.04618987 -0.02778204
#   -0.03778286]
# ...
